# %%
import pandas as pd
# Out:
# /Users/mirunapopa/anaconda2/lib/python2.7/site-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
# !mkdir data/2015_cleaned_data

# %%
df = pd.read_excel('data/Berlin Data - 2015.xlsx',sheetname = "Tab4.6")
# df.to_csv("data/2015_cleaned_data/data_throughout_years.csv",encoding='utf-8')
df
# df.to_csv("data/2015_cleaned_data/age_gender_split.csv")
# Out:
#           Bezirk\n—\nGeschlecht Unnamed: 1   Bevölkerung  \
# 0                           NaN        NaN  ins-\ngesamt
# 1                           NaN        NaN           NaN
# 2                        Mitte           i           350
# 3                           NaN          m         181.3
# 4                           NaN          w         168.7
# 5     Friedrichshain-Kreuzberg           i         268.6
# 6                           NaN          m         138.3
# 7                           NaN          w         130.3
# 8                       Pankow           i         379.3
# 9                           NaN          m         182.2
# 10                          NaN          w         197.1
# 11  Charlottenburg-Wilmersdorf           i         307.5
# 12                          NaN          m         149.7
# 13                          NaN          w         157.7
# 14                     Spandau           i         226.7
# ...

# %%
pd.read_csv("/Users/mirunapopa/Downloads/Berlin Data - 2015 - Bevölkerung im Land Berlin 2015.csv")
# Out:
#                            others     Merkmal (thousands)  Insgesamt Männlich  \
# 0                       Totals *.           Bevölkerung *.   3,485.9  1,705.7
# 1                   Familienstand                 ledig *.   1,757.3    932.0
# 2                             NaN           verheiratet *.   1,212.4    605.7
# 3                             NaN            geschieden *.     321.2    129.9
# 4                             NaN             verwitwet *.     195.0     38.1
# 5                 Alter in Jahren              unter 15 *.     457.1    234.2
# 6                             NaN       15 bis unter 20 *.     141.9     72.1
# 7                             NaN       20 bis unter 25 *.     197.8     92.4
# 8                             NaN       25 bis unter 30 *.     295.9    146.8
# 9                             NaN       30 bis unter 35 *.     282.9    141.8
# 10                            NaN       35 bis unter 40 *.     254.4    129.7
# ...
